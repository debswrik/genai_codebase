# %% [markdown]
# <a href="https://colab.research.google.com/github/debswrik/genai_codebase/blob/main/create_dataset_fine_tuning_llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q datasets
# !pip install huggingface_hub

# %%
from google.colab import userdata
HF_TOKEN = userdata.get("HF_TOKEN")
from huggingface_hub import login
login(HF_TOKEN)

# %%
from datasets import load_dataset
import re

dataset_name = "timdettmers/openassistant-guanaco"
dataset = load_dataset(dataset_name)

# %%
# selects the train dataset
train_dataset = dataset["train"]

# seed ensures same shuffle every time
shuffled_data = train_dataset.shuffle(seed=42)

# selects rows from index 0 to 999
small_dataset = shuffled_data.select(range(1000))

small_dataset.push_to_hub("debsubhra/guanaco-1k")
